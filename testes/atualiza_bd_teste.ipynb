# %%
# importações
import pandas as pd

# %%
# importando planilha
tabela = pd.read_csv(r'C:\projetos\prospeccao-de-clientes\dados\empresas.csv')

# %%
tabela.head()
# Out:
#    Nº            Razão Social    Nome Fantasia                CNPJ  \
# 0   1            Peixoto Ltda      S/A Facilis  87.692.354/0001-22
# 1   2  Carvalho e Filhos Ltda  - ME Voluptatum  07.518.293/0001-42
# 2   3             Duarte Ltda         Ltda. Ea  32.045.897/0001-66
# 3   4            da Mota Ltda          S.A. Ad  41.328.670/0001-19
# 4   5        Aragão - EI Ltda         - ME Sit  14.970.286/0001-42
#
#                             CNAE Principal                 Endereço  \
# 0         4930-2/01 (Transporte de cargas)    Conjunto de Gomes, 51
# 1  6201-5/01 (Desenvolvimento de software)  Feira da Conceição, 271
# 2         6619-3/02 (Serviços financeiros)     Conjunto de da Costa
# 3         4930-2/01 (Transporte de cargas)           Vila das Neves
# 4     2063-1/00 (Fabricação de cosméticos)       Rodovia Rezende, 2
#
#             Cidade Estado    País                  Email          Telefone  \
# 0             Lima     AM  Brasil   melobrenda@moraes.br     0800-387-7840
# 1  Silva do Amparo     AM  Brasil  gabrielly41@viana.net     0500-894-7196
# 2          Cardoso     RR  Brasil          rsouza@da.org   (041) 7515-9179
# 3         Teixeira     RN  Brasil  araujofelipe@costa.br  +55 61 0903 2173
# 4  da Paz Paulista     MS  Brasil  sda-cunha@caldeira.br      51 4197 2076
#
#   Situação Cadastral
# 0            Inativa
# 1            Inativa
# 2            Inativa
# 3            Inativa
# 4            Inativa

# %%
# Criar banco de dados

# %%
# Salvando as informações no banco de dados
